# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import scipy as sp
import glob
import os
from omegaconf import OmegaConf

import matplotlib.pyplot as plt
import pathlib
from matplotlib import cm
plt.style.use('bmh')
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.dpi'] = 300
plt.rcParams['font.size'] = 8
plt.rcParams['legend.fontsize'] = 7
plt.rcParams['legend.loc'] = 'lower right'
plt.rcParams['figure.facecolor'] = '#FFFFFF'

# %%
df = pd.read_csv('dmc_planet_bench.csv')

# %%
envs = [
    'ball_in_cup_catch',
    'cartpole_swingup',
    'cheetah_run',
    'finger_spin',
    'reacher_easy',
    'walker_walk',
]

encoders = [
    'nature_dqn',
]
env_name = {
    'reacher_easy': 'Reacher Easy',
    'cheetah_run': 'Cheetah Run',
    'walker_walk': 'Walker Walk',
    'ball_in_cup_catch': 'Ball In Cup Catch',
    'finger_spin': 'Finger Spin',
    'cartpole_swingup': 'Cartpole Swingup'
}

cutoff = {
    'reacher_easy': 500,
    'walker_walk': 1000,
    'cheetah_run': 2000,
    'finger_spin': 500,
    'ball_in_cup_catch': 500,
    'cartpole_swingup': 500,
}

nrow = 2
ncol = len(envs) // nrow

fig, axs = plt.subplots(nrow, ncol, figsize=(4 * ncol, 3 * nrow))


df['true_step'] = df['episode'] / 1000.



for idx, env in enumerate(envs):
    data = df[df['env'] == env]
    data = data[data['episode'] <= cutoff[env]]
    row = idx // ncol
    col = idx % ncol
    ax = axs[row, col]
    sns.lineplot(x='true_step', y='episode_reward', data=data, ci='sd', hue='Agent', ax=ax)
    ax.set_xlabel('Environment Steps ($\\times 10^6%$)')
    ax.set_ylabel('Episode Return')
    ax.set_title(f'{env_name[env]}')
    

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-9a63381da4f5> in <module>
#      43     data = df[df['env'] == env]
#      44     data = data[data['episode'] <= cutoff[env]]
# ---> 45     row = idx // ncol
#      46     col = idx % ncol
#      47     ax = axs[row, col]
#
# <ipython-input-7-9a63381da4f5> in <module>
#      43     data = df[df['env'] == env]
#      44     data = data[data['episode'] <= cutoff[env]]
# ---> 45     row = idx // ncol
#      46     col = idx % ncol
#      47     ax = axs[row, col]
#
# ~/IDE/pycharm-professional-2020.3.1/pycharm-2020.3.1/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_frame.py in trace_dispatch(self, frame, event, arg)
#     878
#     879                 if plugin_stop:
# --> 880                     stopped_on_plugin = plugin_manager.stop(main_debugger, frame, event, self._args, stop_info, arg, step_cmd)
#     881                 elif stop:
#     882                     if is_line:
#
# ~/IDE/pycharm-professional-2020.3.1/pycharm-2020.3.1/plugins/python/helpers-pro/jupyter_debug/pydev_jupyter_plugin.py in stop(plugin, pydb, frame, event, args, stop_info, arg, step_cmd)
#     163         frame = suspend_jupyter(main_debugger, thread, frame, step_cmd)
#     164         if frame:
# --> 165             main_debugger.do_wait_suspend(thread, frame, event, arg)
#     166             return True
#     167     return False
#
# ~/IDE/pycharm-professional-2020.3.1/pycharm-2020.3.1/plugins/python/helpers/pydev/pydevd.py in do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1139
#    1140         with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1141             self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#    1142
#    1143     def _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread):
#
# ~/IDE/pycharm-professional-2020.3.1/pycharm-2020.3.1/plugins/python/helpers/pydev/pydevd.py in _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1154
#    1155                 self.process_internal_commands()
# -> 1156                 time.sleep(0.01)
#    1157
#    1158         self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#
# KeyboardInterrupt:
